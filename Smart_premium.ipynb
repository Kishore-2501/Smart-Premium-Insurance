# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
df_train = pd.read_csv("/content/train.csv")

# %%
df_train.head()
# Out:
#    id   Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0   0  19.0  Female        10049.0        Married                   1.0
# 1   1  39.0  Female        31678.0       Divorced                   3.0
# 2   2  23.0    Male        25602.0       Divorced                   3.0
# 3   3  21.0    Male       141855.0        Married                   2.0
# 4   4  21.0    Male        39651.0         Single                   1.0
#
#   Education Level     Occupation  Health Score  Location  ... Previous Claims  \
# 0      Bachelor's  Self-Employed     22.598761     Urban  ...             2.0
# 1        Master's            NaN     15.569731     Rural  ...             1.0
# 2     High School  Self-Employed     47.177549  Suburban  ...             1.0
# 3      Bachelor's            NaN     10.938144     Rural  ...             1.0
# 4      Bachelor's  Self-Employed     20.376094     Rural  ...             0.0
#
#    Vehicle Age  Credit Score  Insurance Duration           Policy Start Date  \
# 0         17.0         372.0                 5.0  2023-12-23 15:21:39.134960
# 1         12.0         694.0                 2.0  2023-06-12 15:21:39.111551
# 2         14.0           NaN                 3.0  2023-09-30 15:21:39.221386
# 3          0.0         367.0                 1.0  2024-06-12 15:21:39.226954
# 4          8.0         598.0                 4.0  2021-12-01 15:21:39.252145
#
#   Customer Feedback Smoking Status Exercise Frequency Property Type  \
# 0              Poor             No             Weekly         House
# 1           Average            Yes            Monthly         House
# 2              Good            Yes             Weekly         House
# 3              Poor            Yes              Daily     Apartment
# 4              Poor            Yes             Weekly         House
#
#   Premium Amount
# 0         2869.0
# 1         1483.0
# 2          567.0
# 3          765.0
# 4         2022.0
#
# [5 rows x 21 columns]

# %%
df_train.drop(["id","Policy Start Date"], axis=1, inplace=True)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200000 entries, 0 to 1199999
# Data columns (total 19 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Age                   1181295 non-null  float64
#  1   Gender                1200000 non-null  object
#  2   Annual Income         1155051 non-null  float64
#  3   Marital Status        1181471 non-null  object
#  4   Number of Dependents  1090328 non-null  float64
#  5   Education Level       1200000 non-null  object
#  6   Occupation            841925 non-null   object
#  7   Health Score          1125924 non-null  float64
#  8   Location              1200000 non-null  object
#  9   Policy Type           1200000 non-null  object
#  10  Previous Claims       835971 non-null   float64
#  11  Vehicle Age           1199994 non-null  float64
#  12  Credit Score          1062118 non-null  float64
#  13  Insurance Duration    1199999 non-null  float64
#  14  Customer Feedback     1122176 non-null  object
#  15  Smoking Status        1200000 non-null  object
#  16  Exercise Frequency    1200000 non-null  object
#  17  Property Type         1200000 non-null  object
#  18  Premium Amount        1200000 non-null  float64
# dtypes: float64(9), object(10)
# memory usage: 174.0+ MB

# %%
for i in df_train.columns:
    if df_train[i].isnull().sum() > 0:
        print(i, df_train[i].isnull().sum())
# Out:
# Age 18705
# Annual Income 44949
# Marital Status 18529
# Number of Dependents 109672
# Occupation 358075
# Health Score 74076
# Previous Claims 364029
# Vehicle Age 6
# Credit Score 137882
# Insurance Duration 1
# Customer Feedback 77824

# %%
df_train["Age"] = df_train["Age"].fillna(df_train["Age"].mean()).astype(int)
df_train["Annual Income"] = df_train["Annual Income"].fillna(df_train["Annual Income"].median()).astype(int)
df_train["Marital Status"] = df_train["Marital Status"].apply(lambda i: np.random.choice(["Married", "Single", "Divorced"]) if pd.isnull(i) else i)
df_train["Number of Dependents"] = df_train["Number of Dependents"].fillna(0).astype(int)
df_train["Occupation"] = df_train.apply(lambda i: np.random.choice(["Employed", "Self-Employed","Unemployed"]) if pd.isnull(i["Occupation"]) else i["Occupation"], axis=1)
df_train["Health Score"] = df_train["Health Score"].fillna(df_train["Health Score"].mean()).astype(int)
df_train["Previous Claims"] = df_train["Previous Claims"].fillna(df_train["Previous Claims"].median()).astype(int)
df_train["Vehicle Age"] = df_train["Vehicle Age"].ffill().astype(int)
df_train["Credit Score"] = df_train["Credit Score"].fillna(df_train["Credit Score"].mean()).astype(int)
df_train["Insurance Duration"] = df_train["Insurance Duration"].ffill().astype(int)
df_train["Customer Feedback"] = df_train["Customer Feedback"].apply(lambda i : np.random.choice(["Good", "Poor", "Average"]) if pd.isnull(i) else i)

# %%
df_train.duplicated().sum()
# Out:
# np.int64(1)

# %%
df_train = df_train.drop_duplicates()

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1199999 entries, 0 to 1199999
# Data columns (total 19 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Age                   1199999 non-null  int64
#  1   Gender                1199999 non-null  object
#  2   Annual Income         1199999 non-null  int64
#  3   Marital Status        1199999 non-null  object
#  4   Number of Dependents  1199999 non-null  int64
#  5   Education Level       1199999 non-null  object
#  6   Occupation            1199999 non-null  object
#  7   Health Score          1199999 non-null  int64
#  8   Location              1199999 non-null  object
#  9   Policy Type           1199999 non-null  object
#  10  Previous Claims       1199999 non-null  int64
#  11  Vehicle Age           1199999 non-null  int64
#  12  Credit Score          1199999 non-null  int64
#  13  Insurance Duration    1199999 non-null  int64
#  14  Customer Feedback     1199999 non-null  object
#  15  Smoking Status        1199999 non-null  object
#  16  Exercise Frequency    1199999 non-null  object
#  17  Property Type         1199999 non-null  object
#  18  Premium Amount        1199999 non-null  float64
# dtypes: float64(1), int64(8), object(10)
# memory usage: 183.1+ MB

# %%
for i in df_train.columns:
    print(i, df_train[i].skew(),df_train[i].kurtosis())
# Out:
# Age -0.012125677763782238 -1.1663708477928318
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      84             try:
# ---> 85                 return f(*args, **kwargs)
#      86             except ValueError as e:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py in newfunc(values, axis, **kwargs)
#     476
# --> 477         return func(values, axis=axis, **kwargs)
#     478
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py in nanskew(values, axis, skipna, mask)
#    1239     if values.dtype.kind != "f":
# -> 1240         values = values.astype("f8")
#    1241         count = _get_counts(values.shape, mask, axis)
#
# ValueError: could not convert string to float: 'Female'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-11-177653371.py in <cell line: 0>()
#       1 for i in df_train.columns:
# ----> 2     print(i, df_train[i].skew(),df_train[i].kurtosis())
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in skew(self, axis, skipna, numeric_only, **kwargs)
#    6600         **kwargs,
#    6601     ):
# -> 6602         return NDFrame.skew(self, axis, skipna, numeric_only, **kwargs)
#    6603
#    6604     @doc(make_doc("kurt", ndim=1))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in skew(self, axis, skipna, numeric_only, **kwargs)
#   12440         **kwargs,
#   12441     ) -> Series | float:
# > 12442         return self._stat_function(
#   12443             "skew", nanops.nanskew, axis, skipna, numeric_only, **kwargs
#   12444         )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379         )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6455                     "with non-numeric dtypes."
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#    6459     @Appender(make_doc("any", ndim=1))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      90                 # object arrays that contain strings
#      91                 if is_object_dtype(args[0]):
# ---> 92                     raise TypeError(e) from e
#      93                 raise
#      94
#
# TypeError: could not convert string to float: 'Female'

# %%
for i in df_train.columns:
    if df_train[i].dtype != 'object':
        try:
            print(i, "Skew:", df_train[i].skew(), "Kurtosis:", df_train[i].kurtosis())
        except Exception as e:
            print(f"Could not process {i}: {e}")
# Out:
# Age Skew: -0.012125677763782238 Kurtosis: -1.1663708477928318
# Annual Income Skew: 1.5229536418567273 Kurtosis: 2.0168882570097924
# Number of Dependents Skew: 0.1324118155264467 Kurtosis: -1.378089090201708
# Health Score Skew: 0.2921285092561648 Kurtosis: -0.6400763319105098
# Previous Claims Skew: 1.0876520564176422 Kurtosis: 2.3730432640823387
# Vehicle Age Skew: -0.020402988163971295 Kurtosis: -1.206447174718034
# Credit Score Skew: -0.11846248814560961 Kurtosis: -0.8425395696507265
# Insurance Duration Skew: -0.008792385400219614 Kurtosis: -1.2372513245421706
# Premium Amount Skew: 1.240914230979683 Kurtosis: 1.5185814851329238

# %%
numerical_cols = df_train.select_dtypes(include=['int','float64']).columns

# %%
def detect_outliers_iqr(df,column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 + 1.5*IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)][column]
    return outliers, lower_bound, upper_bound

# %%
print("Outliner Detected")
for col in numerical_cols:
    outliers, lower_bound, upper_bound = detect_outliers_iqr(df_train, col)
    print(f"\n Column :{col}")
    print(f"Number of Outliers: {len(outliers)}")
    print(f"Outlier values : \n{outliers}")
    print(f"Lower bound : {lower_bound:.2f}, Upper bound : {upper_bound:.2f}")
# Out:
# Outliner Detected
#
#  Column :Age
# Number of Outliers: 0
# Outlier values :
# Series([], Name: Age, dtype: int64)
# Lower bound : -4.50, Upper bound : 87.50
#
#  Column :Annual Income
# Number of Outliers: 70466
# Outlier values :
# 3          141855
# 7          127237
# 19         123751
# 29         131038
# 59         147020
#             ...
# 1199891    120884
# 1199942    107739
# 1199952    134908
# 1199956     99860
# 1199967    111949
# Name: Annual Income, Length: 70466, dtype: int64
# Lower bound : -44289.00, Upper bound : 96871.00
#
#  Column :Number of Dependents
# Number of Outliers: 0
# Outlier values :
# Series([], Name: Number of Dependents, dtype: int64)
# Lower bound : -4.50, Upper bound : 7.50
#
#  Column :Health Score
# Number of Outliers: 0
# Outlier values :
# Series([], Name: Health Score, dtype: int64)
# Lower bound : -9.50, Upper bound : 58.50
#
#  Column :Previous Claims
# Number of Outliers: 62066
# Outlier values :
# 41         3
# 56         3
# 63         3
# 70         3
# 105        4
#           ..
# 1199899    3
# 1199918    3
# 1199936    4
# 1199962    3
# 1199983    3
# Name: Previous Claims, Length: 62066, dtype: int64
# Lower bound : -1.50, Upper bound : 2.50
#
#  Column :Vehicle Age
# Number of Outliers: 0
# Outlier values :
# Series([], Name: Vehicle Age, dtype: int64)
# Lower bound : -10.00, Upper bound : 30.00
#
#  Column :Credit Score
# Number of Outliers: 0
# Outlier values :
# Series([], Name: Credit Score, dtype: int64)
# Lower bound : 151.00, Upper bound : 1039.00
#
#  Column :Insurance Duration
# Number of Outliers: 0
# Outlier values :
# Series([], Name: Insurance Duration, dtype: int64)
# Lower bound : -3.00, Upper bound : 13.00
#
#  Column :Premium Amount
# Number of Outliers: 49320
# Outlier values :
# 5          3202.0
# 23         3869.0
# 32         3299.0
# 38         3890.0
# 74         3564.0
#             ...
# 1199945    3308.0
# 1199958    3301.0
# 1199975    3905.0
# 1199978    3080.0
# 1199991    3381.0
# Name: Premium Amount, Length: 49320, dtype: float64
# Lower bound : -978.50, Upper bound : 3001.50

# %%
for i in df_train.select_dtypes(include =["object"]):
        print(i,df_train[i].unique())
# Out:
# Gender ['Female' 'Male']
# Marital Status ['Married' 'Divorced' 'Single']
# Education Level ["Bachelor's" "Master's" 'High School' 'PhD']
# Occupation ['Self-Employed' np.str_('Unemployed') np.str_('Employed')]
# Location ['Urban' 'Rural' 'Suburban']
# Policy Type ['Premium' 'Comprehensive' 'Basic']
# Customer Feedback ['Poor' 'Average' 'Good']
# Smoking Status ['No' 'Yes']
# Exercise Frequency ['Weekly' 'Monthly' 'Daily' 'Rarely']
# Property Type ['House' 'Apartment' 'Condo']

# %%
for col in df_train.select_dtypes(include=["object"]).columns:
    df_train[col] = df_train[col].astype(str).str.replace('"', '').str.strip()

# %%
for i in df_train.select_dtypes(include =["object"]):
        print(i,df_train[i].unique())
# Out:
# Gender ['Female' 'Male']
# Marital Status ['Married' 'Divorced' 'Single']
# Education Level ["Bachelor's" "Master's" 'High School' 'PhD']
# Occupation ['Self-Employed' 'Unemployed' 'Employed']
# Location ['Urban' 'Rural' 'Suburban']
# Policy Type ['Premium' 'Comprehensive' 'Basic']
# Customer Feedback ['Poor' 'Average' 'Good']
# Smoking Status ['No' 'Yes']
# Exercise Frequency ['Weekly' 'Monthly' 'Daily' 'Rarely']
# Property Type ['House' 'Apartment' 'Condo']

# %%
le = LabelEncoder()
for i in df_train.select_dtypes(include =["object"]):
    df_train[i] = le.fit_transform(df_train[i])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1199999 entries, 0 to 1199999
# Data columns (total 19 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Age                   1199999 non-null  int64
#  1   Gender                1199999 non-null  int64
#  2   Annual Income         1199999 non-null  int64
#  3   Marital Status        1199999 non-null  int64
#  4   Number of Dependents  1199999 non-null  int64
#  5   Education Level       1199999 non-null  int64
#  6   Occupation            1199999 non-null  int64
#  7   Health Score          1199999 non-null  int64
#  8   Location              1199999 non-null  int64
#  9   Policy Type           1199999 non-null  int64
#  10  Previous Claims       1199999 non-null  int64
#  11  Vehicle Age           1199999 non-null  int64
#  12  Credit Score          1199999 non-null  int64
#  13  Insurance Duration    1199999 non-null  int64
#  14  Customer Feedback     1199999 non-null  int64
#  15  Smoking Status        1199999 non-null  int64
#  16  Exercise Frequency    1199999 non-null  int64
#  17  Property Type         1199999 non-null  int64
#  18  Premium Amount        1199999 non-null  float64
# dtypes: float64(1), int64(18)
# memory usage: 183.1 MB

# %%
df_train.head(20)
# Out:
#     Age  Gender  Annual Income  Marital Status  Number of Dependents  \
# 0    19       0          10049               1                     1
# 1    39       0          31678               0                     3
# 2    23       1          25602               0                     3
# 3    21       1         141855               1                     2
# 4    21       1          39651               2                     1
# 5    29       1          45963               1                     1
# 6    41       1          40336               1                     0
# 7    48       0         127237               0                     2
# 8    21       1           1733               0                     3
# 9    44       1          52447               1                     2
# 10   56       0           8054               1                     1
# 11   23       1          30983               2                     3
# 12   25       0          23706               2                     4
# 13   44       0          70893               2                     0
# 14   40       0          23897               0                     0
# 15   18       1           6076               1                     2
# 16   59       0          28266               0                     2
# 17   34       0          45907               0                     4
# 18   18       1          29071               1                     0
# 19   40       0         123751               2                     2
#
#     Education Level  Occupation  Health Score  Location  Policy Type  \
# 0                 0           1            22         2            2
# 1                 2           2            15         0            1
# 2                 1           1            47         1            2
# 3                 0           2            10         0            0
# 4                 0           1            20         0            2
# 5                 0           2            33         2            2
# 6                 3           0            25         0            0
# 7                 1           0             5         1            1
# 8                 0           1            17         2            2
# 9                 2           0            20         2            1
# 10                0           2            25         0            2
# 11                2           2             5         2            2
# 12                2           0             4         2            1
# 13                0           2            55         1            2
# 14                1           1            29         1            0
# 15                1           0             7         2            2
# 16                3           2            21         2            0
# 17                1           1            24         1            1
# 18                0           0            20         0            2
# 19                2           1            24         1            2
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0                 2           17           372                   5
# 1                 1           12           694                   2
# 2                 1           14           592                   3
# 3                 1            0           367                   1
# 4                 0            8           598                   4
# 5                 2            4           614                   5
# 6                 2            8           807                   6
# 7                 1           11           398                   5
# 8                 1           10           685                   8
# 9                 1            9           635                   3
# 10                1            8           431                   8
# 11                1            6           597                   8
# 12                2           19           592                   2
# 13                0            3           511                   6
# 14                2           15           498                   1
# 15                1           12           584                   5
# 16                0           16           592                   3
# 17                0            0           694                   8
# 18                1            5           592                   3
# 19                0            8           420                   2
#
#     Customer Feedback  Smoking Status  Exercise Frequency  Property Type  \
# 0                   2               0                   3              2
# 1                   0               1                   1              2
# 2                   1               1                   3              2
# 3                   2               1                   0              0
# 4                   2               1                   3              2
# 5                   0               0                   3              2
# 6                   2               0                   3              2
# 7                   0               0                   2              1
# 8                   0               0                   1              1
# 9                   2               0                   0              1
# 10                  0               0                   1              1
# 11                  1               0                   2              1
# 12                  2               1                   3              0
# 13                  1               1                   3              2
# 14                  1               0                   2              1
# 15                  1               1                   1              0
# 16                  0               1                   3              1
# 17                  2               1                   0              1
# 18                  2               1                   2              0
# 19                  1               1                   2              1
#
#     Premium Amount
# 0           2869.0
# 1           1483.0
# 2            567.0
# 3            765.0
# 4           2022.0
# 5           3202.0
# 6            439.0
# 7            111.0
# 8            213.0
# 9             64.0
# 10           857.0
# 11          1447.0
# 12           703.0
# 13          1847.0
# 14            30.0
# 15           849.0
# 16           183.0
# 17           643.0
# 18           787.0
# 19            40.0

# %%
features = ['Age','Annual Income','Number of Dependents','Health Score','Previous Claims','Vehicle Age','Credit Score','Insurance Duration']
corr_1= df_train[features].corr()
plt.figure(figsize=(16,10))
sns.heatmap(corr_1, annot=True, fmt = ".2f", cmap = "BuPu");

# %%
df_test = pd.read_csv("/content/test.csv")

# %%
df_test.head(20)
# Out:
#          id   Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0   1200000  28.0  Female         2310.0            NaN                   4.0
# 1   1200001  31.0  Female       126031.0        Married                   2.0
# 2   1200002  47.0  Female        17092.0       Divorced                   0.0
# 3   1200003  28.0  Female        30424.0       Divorced                   3.0
# 4   1200004  24.0    Male        10863.0       Divorced                   2.0
# 5   1200005  43.0    Male        52370.0        Married                   2.0
# 6   1200006  21.0  Female         5896.0        Married                   3.0
# 7   1200007  44.0    Male        31855.0       Divorced                   3.0
# 8   1200008  32.0  Female        76463.0       Divorced                   4.0
# 9   1200009  48.0  Female        27982.0        Married                   2.0
# 10  1200010  44.0    Male        24238.0       Divorced                   0.0
# 11  1200011  63.0    Male         5824.0       Divorced                   2.0
# 12  1200012  23.0  Female        44943.0         Single                   4.0
# 13  1200013  60.0    Male        44769.0        Married                   2.0
# 14  1200014  46.0  Female        66984.0         Single                   0.0
# 15  1200015  47.0  Female        46256.0       Divorced                   3.0
# 16  1200016  43.0    Male        15259.0        Married                   NaN
# 17  1200017  47.0    Male            NaN       Divorced                   1.0
# 18  1200018  42.0  Female         1807.0        Married                   1.0
# 19  1200019  64.0    Male        88483.0       Divorced                   4.0
#
#    Education Level     Occupation  Health Score  Location    Policy Type  \
# 0       Bachelor's  Self-Employed      7.657981     Rural          Basic
# 1         Master's  Self-Employed     13.381379  Suburban        Premium
# 2              PhD     Unemployed     24.354527     Urban  Comprehensive
# 3              PhD  Self-Employed      5.136225  Suburban  Comprehensive
# 4      High School     Unemployed     11.844155  Suburban        Premium
# 5       Bachelor's            NaN      5.386224  Suburban          Basic
# 6         Master's            NaN     14.773963     Rural  Comprehensive
# 7       Bachelor's            NaN     20.847900  Suburban        Premium
# 8              PhD            NaN     22.988787  Suburban          Basic
# 9      High School            NaN     43.567433     Urban        Premium
# 10        Master's     Unemployed     20.769332     Rural        Premium
# 11        Master's     Unemployed     13.430514     Urban  Comprehensive
# 12      Bachelor's     Unemployed     43.968639     Rural        Premium
# 13        Master's  Self-Employed     20.837186  Suburban  Comprehensive
# 14      Bachelor's     Unemployed     16.490747     Urban        Premium
# 15        Master's  Self-Employed     46.936125     Rural  Comprehensive
# 16             PhD       Employed      7.922608  Suburban          Basic
# 17      Bachelor's       Employed     25.713837     Urban          Basic
# 18             PhD     Unemployed     13.149865     Urban  Comprehensive
# 19      Bachelor's     Unemployed      4.362879  Suburban          Basic
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0               NaN         19.0           NaN                 1.0
# 1               NaN         14.0         372.0                 8.0
# 2               NaN         16.0         819.0                 9.0
# 3               1.0          3.0         770.0                 5.0
# 4               NaN         14.0         755.0                 7.0
# 5               NaN         15.0         432.0                 2.0
# 6               1.0         14.0         321.0                 8.0
# 7               NaN          8.0         712.0                 1.0
# 8               0.0          1.0         540.0                 2.0
# 9               1.0         15.0         757.0                 7.0
# 10              0.0         11.0         408.0                 3.0
# 11              0.0          9.0         849.0                 9.0
# 12              NaN         11.0         818.0                 2.0
# 13              1.0         14.0         621.0                 4.0
# 14              1.0         12.0         319.0                 2.0
# 15              NaN         18.0         542.0                 1.0
# 16              NaN         13.0         602.0                 5.0
# 17              0.0         16.0         595.0                 1.0
# 18              NaN          2.0         468.0                 6.0
# 19              1.0         13.0         318.0                 1.0
#
#              Policy Start Date Customer Feedback Smoking Status  \
# 0   2023-06-04 15:21:39.245086              Poor            Yes
# 1   2024-04-22 15:21:39.224915              Good            Yes
# 2   2023-04-05 15:21:39.134960           Average            Yes
# 3   2023-10-25 15:21:39.134960              Poor            Yes
# 4   2021-11-26 15:21:39.259788           Average             No
# 5   2022-07-08 15:21:39.223901               NaN             No
# 6   2023-11-12 15:21:39.288099              Good             No
# 7   2021-03-12 15:21:39.149731              Poor            Yes
# 8   2021-07-08 15:21:39.169102           Average             No
# 9   2021-02-15 15:21:39.134960              Good            Yes
# 10  2021-06-25 15:21:39.134960              Poor             No
# 11  2024-05-07 15:21:39.123711              Good            Yes
# 12  2022-10-16 15:21:39.229482              Poor             No
# 13  2020-01-21 15:21:39.204790              Good             No
# 14  2020-04-07 15:21:39.246098              Poor             No
# 15  2024-08-09 15:21:39.090124              Poor             No
# 16  2022-11-29 15:21:39.254678              Good            Yes
# 17  2021-01-19 15:21:39.274993           Average             No
# 18  2023-03-05 15:21:39.119168              Good             No
# 19  2024-04-26 15:21:39.111551              Poor            Yes
#
#    Exercise Frequency Property Type
# 0              Weekly         House
# 1              Rarely     Apartment
# 2             Monthly         Condo
# 3               Daily         House
# 4              Weekly         House
# 5              Rarely         Condo
# 6             Monthly         Condo
# 7             Monthly     Apartment
# 8              Weekly     Apartment
# 9               Daily         House
# 10              Daily         Condo
# 11             Weekly         House
# 12            Monthly     Apartment
# 13             Weekly     Apartment
# 14            Monthly         House
# 15             Rarely     Apartment
# 16             Weekly         Condo
# 17            Monthly         House
# 18              Daily         Condo
# 19              Daily         Condo

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800000 entries, 0 to 799999
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    800000 non-null  int64
#  1   Age                   787511 non-null  float64
#  2   Gender                800000 non-null  object
#  3   Annual Income         770140 non-null  float64
#  4   Marital Status        787664 non-null  object
#  5   Number of Dependents  726870 non-null  float64
#  6   Education Level       800000 non-null  object
#  7   Occupation            560875 non-null  object
#  8   Health Score          750551 non-null  float64
#  9   Location              800000 non-null  object
#  10  Policy Type           800000 non-null  object
#  11  Previous Claims       557198 non-null  float64
#  12  Vehicle Age           799997 non-null  float64
#  13  Credit Score          708549 non-null  float64
#  14  Insurance Duration    799998 non-null  float64
#  15  Policy Start Date     800000 non-null  object
#  16  Customer Feedback     747724 non-null  object
#  17  Smoking Status        800000 non-null  object
#  18  Exercise Frequency    800000 non-null  object
#  19  Property Type         800000 non-null  object
# dtypes: float64(8), int64(1), object(11)
# memory usage: 122.1+ MB

# %%
df_test.drop(["id","Policy Start Date"], axis=1, inplace=True)

# %%
for i in df_test.columns:
    if df_test[i].isnull().sum() > 0:
        print(i, df_test[i].isnull().sum())
# Out:
# Age 12489
# Annual Income 29860
# Marital Status 12336
# Number of Dependents 73130
# Occupation 239125
# Health Score 49449
# Previous Claims 242802
# Vehicle Age 3
# Credit Score 91451
# Insurance Duration 2
# Customer Feedback 52276

# %%
df_test["Age"] = df_test.groupby(["Gender", "Marital Status", "Number of Dependents"])["Age"]\
.transform(lambda x: x.fillna(x.mean()))
df_test["Age"] = df_test["Age"].fillna(df_test["Age"].mean())
df_test["Annual Income"] = df_test["Annual Income"].fillna(df_test["Annual Income"].median()).astype(int)
df_test["Marital Status"] = df_test["Marital Status"].apply(lambda i: np.random.choice(["Married", "Single", "Divorced"]) if pd.isnull(i) else i)
df_test["Number of Dependents"] = df_test["Number of Dependents"].fillna(0).astype(int)
df_test["Occupation"] = df_test.apply(lambda i: np.random.choice(["Employed", "Self-Employed","Unemployed"]) if pd.isnull(i["Occupation"]) else i["Occupation"], axis=1)
df_test["Health Score"] = df_test["Health Score"].fillna(df_test["Health Score"].mean()).astype(int)
df_test["Previous Claims"] = df_test["Previous Claims"].fillna(df_test["Previous Claims"].median()).astype(int)
df_test["Vehicle Age"]=df_test["Vehicle Age"].ffill().astype(int)
df_test["Credit Score"] = df_test["Credit Score"].fillna(df_test["Credit Score"].mean()).astype(int)
df_test["Insurance Duration"] = df_test["Insurance Duration"].ffill().astype(int)
df_test["Customer Feedback"]=df_test["Customer Feedback"].apply(lambda i : np.random.choice(["Good","Poor","Average"] )if pd.isnull(i) else i)

# %%
df_test.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800000 entries, 0 to 799999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Age                   800000 non-null  float64
#  1   Gender                800000 non-null  object
#  2   Annual Income         800000 non-null  int64
#  3   Marital Status        800000 non-null  object
#  4   Number of Dependents  800000 non-null  int64
#  5   Education Level       800000 non-null  object
#  6   Occupation            800000 non-null  object
#  7   Health Score          800000 non-null  int64
#  8   Location              800000 non-null  object
#  9   Policy Type           800000 non-null  object
#  10  Previous Claims       800000 non-null  int64
#  11  Vehicle Age           800000 non-null  int64
#  12  Credit Score          800000 non-null  int64
#  13  Insurance Duration    800000 non-null  int64
#  14  Customer Feedback     800000 non-null  object
#  15  Smoking Status        800000 non-null  object
#  16  Exercise Frequency    800000 non-null  object
#  17  Property Type         800000 non-null  object
# dtypes: float64(1), int64(7), object(10)
# memory usage: 109.9+ MB

# %%
le = LabelEncoder()
for i in df_train.select_dtypes(include = "object"):
    df_train[i] = le.fit_transform(df_train[i])

# %%
for i in df_train.columns:
    print(i,df_train[i].unique())
# Out:
# Age [19 39 23 21 29 41 48 44 56 25 40 18 59 34 22 46 49 42 43 64 52 37 58 50
#  35 61 31 54 45 30 33 28 62 53 47 27 38 63 32 36 20 51 55 57 24 60 26]
# Gender [0 1]
# Annual Income [ 10049  31678  25602 ... 125361 137940  40368]
# Marital Status [1 0 2]
# Number of Dependents [1 3 2 0 4]
# Education Level [0 2 1 3]
# Occupation [1 2 0]
# Health Score [22 15 47 10 20 33 25  5 17  4 55 29  7 21 24 26 27 23 31 41 32 14 19 38
#  18 28 40 36 37 35 51 50 45 30 13 16 39 43 34 46 11 42 49  6 52 12  3  9
#  48  8 44 58 54 53  2 57 56]
# Location [2 0 1]
# Policy Type [2 1 0]
# Previous Claims [2 1 0 3 4 5 6 7 8 9]
# Vehicle Age [17 12 14  0  8  4 11 10  9  6 19  3 15 16  5  7 18  1  2 13]
# Credit Score [372 694 592 367 598 614 807 398 685 635 431 597 511 498 584 420 595 799
#  773 798 543 416 425 486 795 495 449 803 421 695 713 589 812 382 469 530
#  538 842 575 794 836 784 439 381 801 624 497 359 662 703 426 331 679 375
#  321 531 622 464 418 534 454 502 823 319 660 371 562 488 577 791 638 438
#  779 310 748 392 446 593 576 493 479 826 332 616 716 602 343 377 788 758
#  571 554 682 641 360 522 728 388 535 519 651 829 620 776 835 432 607 705
#  644 686 797 509 831 529 774 843 738 781 766 364 349 692 574 324 632 379
#  434 442 764 429 683 770 696 611 436 482 636 609 374 566 537 648 578 707
#  581 541 845 441 718 630 586 780 401 757 646 752 665 506 336 430 424 459
#  786 447 339 516 590 456 334 645 520 453 647 588 585 489 532 772 380 490
#  573 712 437 342 792 583 487 587 539 793 691 759 494 762 653 391 472 560
#  659 810 734 731 765 407 440 656 815 415 527 613 402 783 751 658 465 335
#  559 536 603 657 742 846 739 689 468 513 328 723 626 505 617 698 725 423
#  744 338 743 348 389 450 833 704 667 652 664 825 496 504 629 580 678 572
#  345 397 346 414 460 841 596 674 822 483 405 314 565 693 485 832 749 830
#  451 387 561 775 326 302 393 727 463 329 730 304 817 445 768 567 639 491
#  582 542 761 819 778 523 787 350 618 548 466 702 394 844 508 756 805 476
#  820 625 544 767 473 521 785 839 553 828 325 461 547 594 724 827 309 378
#  492 687 722 452 568 816 470 555 709 417 719 591 396 834 533 457 604 796
#  477 631 341 433 847 637 684 386 720 499 733 697 706 745 721 612 552 351
#  365 818 808 569 481 715 406 564 501 729 524 361 484 736 518 467 790 782
#  699 760 403 563 316 710 755 802 608 376 318 711 308 848 557 681 680 478
#  601 821 558 655 301 507 546 824 677 404 320 663 356 410 654 673 337 619
#  621 462 672 763 806 649 627 688 849 528 643 549 746 732 515 800 444 579
#  671 811 615 737 661 306 363 556 714 690 312 352 769 362 642 753 307 623
#  411 510 634 354 628 366 838 385 353 837 599 500 668 300 373 814 474 409
#  771 726 358 413 471 514 551 650 475 676 384 419 754 517 311 813 443 368
#  701 303 750 804 357 455 395 708 545 717 777 313 315 600 422 383 340 540
#  512 370 435 427 408 809 605 633 675 503 347 740 327 412 322 526 369 840
#  448 400 317 610 570 735 344 480 670 399 666 669 550 458 390 333 789 741
#  700 640 525 305 323 355 747 606 330 428]
# Insurance Duration [5 2 3 1 4 6 8 9 7]
# Customer Feedback [2 0 1]
# Smoking Status [0 1]
# Exercise Frequency [3 1 0 2]
# Property Type [2 0 1]
# Premium Amount [2869. 1483.  567. ... 4937. 4507. 4925.]

# %%
df_train['Premium Amount'] = df_train['Premium Amount'].astype('int64')

# %%
df_train.head(10)
# Out:
#    Age  Gender  Annual Income  Marital Status  Number of Dependents  \
# 0   19       0          10049               1                     1
# 1   39       0          31678               0                     3
# 2   23       1          25602               0                     3
# 3   21       1         141855               1                     2
# 4   21       1          39651               2                     1
# 5   29       1          45963               1                     1
# 6   41       1          40336               1                     0
# 7   48       0         127237               0                     2
# 8   21       1           1733               0                     3
# 9   44       1          52447               1                     2
#
#    Education Level  Occupation  Health Score  Location  Policy Type  \
# 0                0           1            22         2            2
# 1                2           2            15         0            1
# 2                1           1            47         1            2
# 3                0           2            10         0            0
# 4                0           1            20         0            2
# 5                0           2            33         2            2
# 6                3           0            25         0            0
# 7                1           0             5         1            1
# 8                0           1            17         2            2
# 9                2           0            20         2            1
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0                2           17           372                   5
# 1                1           12           694                   2
# 2                1           14           592                   3
# 3                1            0           367                   1
# 4                0            8           598                   4
# 5                2            4           614                   5
# 6                2            8           807                   6
# 7                1           11           398                   5
# 8                1           10           685                   8
# 9                1            9           635                   3
#
#    Customer Feedback  Smoking Status  Exercise Frequency  Property Type  \
# 0                  2               0                   3              2
# 1                  0               1                   1              2
# 2                  1               1                   3              2
# 3                  2               1                   0              0
# 4                  2               1                   3              2
# 5                  0               0                   3              2
# 6                  2               0                   3              2
# 7                  0               0                   2              1
# 8                  0               0                   1              1
# 9                  2               0                   0              1
#
#    Premium Amount
# 0            2869
# 1            1483
# 2             567
# 3             765
# 4            2022
# 5            3202
# 6             439
# 7             111
# 8             213
# 9              64

# %%
x= df_train.drop(["Premium Amount"],axis=1)

# %%
x.head()
# Out:
#    Age  Gender  Annual Income  Marital Status  Number of Dependents  \
# 0   19       0          10049               1                     1
# 1   39       0          31678               0                     3
# 2   23       1          25602               0                     3
# 3   21       1         141855               1                     2
# 4   21       1          39651               2                     1
#
#    Education Level  Occupation  Health Score  Location  Policy Type  \
# 0                0           1            22         2            2
# 1                2           2            15         0            1
# 2                1           1            47         1            2
# 3                0           2            10         0            0
# 4                0           1            20         0            2
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0                2           17           372                   5
# 1                1           12           694                   2
# 2                1           14           592                   3
# 3                1            0           367                   1
# 4                0            8           598                   4
#
#    Customer Feedback  Smoking Status  Exercise Frequency  Property Type
# 0                  2               0                   3              2
# 1                  0               1                   1              2
# 2                  1               1                   3              2
# 3                  2               1                   0              0
# 4                  2               1                   3              2

# %%
y=df_train["Premium Amount"]

# %%
y.head()
# Out:
# 0    2869
# 1    1483
# 2     567
# 3     765
# 4    2022
# Name: Premium Amount, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.05)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (1199999, 18) (1139999, 18) (60000, 18)

# %%
print(y.shape,y_train.shape,y_test.shape)
# Out:
# (1199999,) (1139999,) (60000,)

# %%
from sklearn.ensemble import RandomForestRegressor
model1 = RandomForestRegressor( n_estimators=500, max_depth=7,min_samples_split=2,min_samples_leaf=1,max_features='sqrt',random_state=42)
model1.fit(x_train,y_train)
print("Model training complete.")
# Out:
# Model training complete.

# %%
y_pred = model1.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print("R2_score = ",r2_score(y_test,y_pred),"MSE = ",mean_squared_error(y_test,y_pred),"MAE = ",mean_absolute_error(y_test,y_pred))
# Out:
# R2_score =  0.01753650231149617 MSE =  738895.4093815065 MAE =  664.4527236191044

# %%
from sklearn.ensemble import GradientBoostingRegressor
model2 = GradientBoostingRegressor().fit(x_train,y_train)
print("Model training complete.")
# Out:
# Model training complete.

# %%
y_pred = model2.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print("R2_score = ",r2_score(y_test,y_pred),"MSE = ",mean_squared_error(y_test,y_pred),"MAE = ",mean_absolute_error(y_test,y_pred))
# Out:
# R2_score =  0.02580313512714516 MSE =  732678.2043119068 MAE =  659.51175094287

# %%
from sklearn.ensemble import AdaBoostRegressor
model3 = AdaBoostRegressor().fit(x_train,y_train)
y_pred = model3.predict(x_test)
print("R2_score = ",r2_score(y_test,y_pred),"MSE = ",mean_squared_error(y_test,y_pred),"MAE = ",mean_absolute_error(y_test,y_pred))

# %%
from xgboost import XGBRegressor
model4 = XGBRegressor().fit(x_train,y_train)
y_pred = model4.predict(x_test)
print("R2_score = ",r2_score(y_test,y_pred),"MSE = ",mean_squared_error(y_test,y_pred),"MAE = ",mean_absolute_error(y_test,y_pred))
# Out:
# R2_score =  0.03557753562927246 MSE =  725327.0 MAE =  649.9730224609375

# %%
from sklearn.svm import SVR
model5 = SVR().fit(x_train,y_train)
y_pred = model5.predict(x_test)
print("R2_score = ",r2_score(y_test,y_pred),"MSE = ",mean_squared_error(y_test,y_pred),"MAE = ",mean_absolute_error(y_test,y_pred))

# %%
input_values = [[35, 1, 75000, 1, 2, 2, 4, 80, 1, 0, 1, 3, 700, 5, 2, 0, 1, 0]]

# %%
input_df = pd.DataFrame(input_values)
input_df.columns = x_train.columns
predicted_premium = model1.predict(input_df)
print("Predicted Premium Amount:", round(predicted_premium[0]))
# Out:
# Predicted Premium Amount: 1119
